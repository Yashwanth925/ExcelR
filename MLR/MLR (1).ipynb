# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("ToyotaCorolla - MLR.csv")
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# 3             4      5    1165
# 4             4      5    1170
# ...         ...    ...     ...
# 1431          4      5    1025
# 1432          4      5    1015
# 1433          4      5    1015
# 1434          4      5    1015
# 1435          4      5    1114
#
# [1436 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age_08_04  1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   cc         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Cylinders  1436 non-null   int64
#  9   Gears      1436 non-null   int64
#  10  Weight     1436 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 123.5+ KB

# %%
 #1.Perform exploratory data analysis (EDA) to gain insights into the dataset

# 1. Check for missing values
df.isnull().sum()
# Out:
# Price        0
# Age_08_04    0
# KM           0
# Fuel_Type    0
# HP           0
# Automatic    0
# cc           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
# 2. Get descriptive statistics
df.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears      Weight
# count   1436.00000  1436.000000     1436.0  1436.000000  1436.00000
# mean    1576.85585     4.033426        4.0     5.026462  1072.45961
# std      424.38677     0.952677        0.0     0.188510    52.64112
# min     1300.00000     2.000000        4.0     3.000000  1000.00000
# 25%     1400.00000     3.000000        4.0     5.000000  1040.00000
# 50%     1600.00000     4.000000        4.0     5.000000  1070.00000
# 75%     1600.00000     5.000000        4.0     5.000000  1085.00000
# max    16000.00000     5.000000        4.0     6.000000  1615.00000

# %%
# Visualize relationships between variables
import matplotlib.pyplot as plt
plt.scatter(df['Price'], df['Age_08_04'])
plt.show()

# %%
# Scatter matrix for the entire DataFrame
pd.plotting.scatter_matrix(df, figsize=(15, 15))
plt.suptitle('Scatter Matrix for the Entire DataFrame')
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:100: UserWarning: Attempting to set identical left == right == 4.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# C:\Users\user\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:101: UserWarning: Attempting to set identical bottom == top == 4.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# C:\Users\user\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\misc.py:91: UserWarning: Attempting to set identical left == right == 4.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[i])

# %%
 #Provide visualizations and summary statistics of the variables

# Visualize the distribution of each variable
df.hist(figsize=(10, 8))
plt.show()

# %%
# transforming a categorical data into numerical data 
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

df["Fuel_Type"] = LE.fit_transform(df["Fuel_Type"])

df["Fuel_Type"]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1431    2
# 1432    2
# 1433    2
# 1434    2
# 1435    2
# Name: Fuel_Type, Length: 1436, dtype: int32

# %%
# Calculate summary statistics
df.describe()
# Out:
#               Price    Age_08_04             KM    Fuel_Type           HP  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749     1.868384   101.502089
# std     3626.964585    18.599988   37506.448872     0.371572    14.981080
# min     4350.000000     1.000000       1.000000     0.000000    69.000000
# 25%     8450.000000    44.000000   43000.000000     2.000000    90.000000
# 50%     9900.000000    61.000000   63389.500000     2.000000   110.000000
# 75%    11950.000000    70.000000   87020.750000     2.000000   110.000000
# max    32500.000000    80.000000  243000.000000     2.000000   192.000000
#
#          Automatic           cc        Doors  Cylinders        Gears  \
# count  1436.000000   1436.00000  1436.000000     1436.0  1436.000000
# mean      0.055710   1576.85585     4.033426        4.0     5.026462
# std       0.229441    424.38677     0.952677        0.0     0.188510
# min       0.000000   1300.00000     2.000000        4.0     3.000000
# 25%       0.000000   1400.00000     3.000000        4.0     5.000000
# 50%       0.000000   1600.00000     4.000000        4.0     5.000000
# 75%       0.000000   1600.00000     5.000000        4.0     5.000000
# max       1.000000  16000.00000     5.000000        4.0     6.000000
#
#            Weight
# count  1436.00000
# mean   1072.45961
# std      52.64112
# min    1000.00000
# 25%    1040.00000
# 50%    1070.00000
# 75%    1085.00000
# max    1615.00000

# %%
df.corr()
# Out:
#               Price  Age_08_04        KM  Fuel_Type        HP  Automatic  \
# Price      1.000000  -0.876590 -0.569960  -0.022157  0.314990   0.033081
# Age_08_04 -0.876590   1.000000  0.505672   0.080261 -0.156622   0.031717
# KM        -0.569960   0.505672  1.000000  -0.420586 -0.333538  -0.081854
# Fuel_Type -0.022157   0.080261 -0.420586   1.000000  0.409476   0.069718
# HP         0.314990  -0.156622 -0.333538   0.409476  1.000000   0.013144
# Automatic  0.033081   0.031717 -0.081854   0.069718  0.013144   1.000000
# cc         0.126389  -0.098084  0.102683  -0.277239  0.035856   0.066740
# Doors      0.185326  -0.148359 -0.036197  -0.026935  0.092424  -0.027654
# Cylinders       NaN        NaN       NaN        NaN       NaN        NaN
# Gears      0.063104  -0.005364  0.015023   0.069655  0.209477  -0.098555
# Weight     0.581198  -0.470253 -0.028598  -0.505303  0.089614   0.057249
#
#                  cc     Doors  Cylinders     Gears    Weight
# Price      0.126389  0.185326        NaN  0.063104  0.581198
# Age_08_04 -0.098084 -0.148359        NaN -0.005364 -0.470253
# KM         0.102683 -0.036197        NaN  0.015023 -0.028598
# Fuel_Type -0.277239 -0.026935        NaN  0.069655 -0.505303
# HP         0.035856  0.092424        NaN  0.209477  0.089614
# Automatic  0.066740 -0.027654        NaN -0.098555  0.057249
# cc         1.000000  0.079903        NaN  0.014629  0.335637
# Doors      0.079903  1.000000        NaN -0.160141  0.302618
# Cylinders       NaN       NaN        NaN       NaN       NaN
# Gears      0.014629 -0.160141        NaN  1.000000  0.020613
# Weight     0.335637  0.302618        NaN  0.020613  1.000000

# %%
#Pre process the data to apply the MLR.

# 1. Handle missing values
df.fillna(df.mean(), inplace=True)

# %%
# Split data into features (X) and target variable (y)
X = df[['Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cc', 'Doors', 'Weight', 'Cylinders','Gears']]
Y = df['Price']

# %%
# Standardize numerical features
from sklearn.preprocessing import StandardScaler
SS= StandardScaler()
X_SS=SS.fit_transform(X)
X_SS=pd.DataFrame(X_SS)
X_SS.columns = list(X)
X_SS
# Out:
#       Age_08_04        KM  Fuel_Type        HP  Automatic        cc     Doors  \
# 0     -1.771966 -0.574695  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# 1     -1.771966  0.117454  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# 2     -1.718184 -0.715386  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# 3     -1.610620 -0.547650  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# 4     -1.395491 -0.801028  -2.337868 -0.768042  -0.242893  0.997419 -1.085139
# ...         ...       ...        ...       ...        ...       ...       ...
# 1431   0.702015 -1.279939   0.354336 -1.035138  -0.242893 -0.652594 -1.085139
# 1432   0.863362 -1.321120   0.354336 -1.035138  -0.242893 -0.652594 -1.085139
# 1433   0.809579 -1.374036   0.354336 -1.035138  -0.242893 -0.652594 -1.085139
# 1434   0.755797 -1.376703   0.354336 -1.035138  -0.242893 -0.652594 -1.085139
# 1435   1.078490 -1.827849   0.354336  0.567440  -0.242893  0.054555  1.014941
#
#         Weight  Cylinders     Gears
# 0     1.758561        0.0 -0.140425
# 1     1.758561        0.0 -0.140425
# 2     1.758561        0.0 -0.140425
# 3     1.758561        0.0 -0.140425
# 4     1.853577        0.0 -0.140425
# ...        ...        ...       ...
# 1431 -0.901883        0.0 -0.140425
# 1432 -1.091915        0.0 -0.140425
# 1433 -1.091915        0.0 -0.140425
# 1434 -1.091915        0.0 -0.140425
# 1435  0.789399        0.0 -0.140425
#
# [1436 rows x 10 columns]

# %%
#2.Split the dataset into training and testing sets (e.g., 80% training, 20% testing).
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X_SS,Y,test_size= 0.2,random_state=42)

# %%
#3.Build a multiple linear regression model using the training dataset. Interpret the coefficients of the model. Build minimum of 3 different models.

# %%
#4.Evaluate the performance of the model using appropriate evaluation metrics on the testing dataset.

# %%
#model 1
X = df[['Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cc', 'Doors', 'Weight', 'Cylinders','Gears']]
Y = df['Price']
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Create and fit the MLR model
mlr_model = LinearRegression()
mlr_model.fit(X_train, Y_train)

# Make predictions on the testing data
y_pred = mlr_model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(Y_test, y_pred)
rmse = mean_squared_error(Y_test, y_pred, squared=False)
r2 = r2_score(Y_test, y_pred)

print("Model 1 Results:")
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R-squared (R2):", r2)
print("vif value:", 1/(1-r2))
# Out:
# Model 1 Results:
# Mean Squared Error (MSE): 2096851.1400177032
# Root Mean Squared Error (RMSE): 1448.0508071258078
# R-squared (R2): 0.8428476112018002
# vif value: 6.3632503943933365

# %%
#model 2
X1 = df[['Age_08_04', 'KM', 'HP', 'cc', 'Weight', 'Cylinders','Gears']]
Y1 = df['Price']

X1_train, X1_test, Y1_train, Y1_test = train_test_split(X1, Y1, test_size=0.2, random_state=42)

mlr_model1 = LinearRegression()
mlr_model1.fit(X1_train, Y1_train)

y1_pred = mlr_model1.predict(X1_test)

mse1 = mean_squared_error(Y1_test, y1_pred)
rmse1 = mean_squared_error(Y1_test, y1_pred, squared=False)
r2_1 = r2_score(Y1_test, y1_pred)

print("Model 2 Results:")
print("Mean Squared Error (MSE):", mse1)
print("Root Mean Squared Error (RMSE):", rmse1)
print("R-squared (R2):", r2_1)
print("vif value:", 1/(1-r2_1))

# Model 3: 
X2 = df[['Fuel_Type', 'Automatic', 'Doors', 'Age_08_04', 'KM', 'HP', 'cc', 'Weight', 'Cylinders','Gears']]
Y2 = df['Price']

X2_train, X2_test, Y2_train, Y2_test = train_test_split(X2, Y2, test_size=0.2, random_state=42)

mlr_model2 = LinearRegression()
mlr_model2.fit(X2_train, Y2_train)

y2_pred = mlr_model2.predict(X2_test)

mse2 = mean_squared_error(Y2_test, y2_pred)
rmse2 = mean_squared_error(Y2_test, y2_pred, squared=False)
r2_2 = r2_score(Y2_test, y2_pred)

print("Model 3 Results:")
print("Mean Squared Error (MSE):", mse2)
print("Root Mean Squared Error (RMSE):", rmse2)
print("R-squared (R2):", r2_2)
print("vif value:", 1/(1-r2_2))
# Out:
# Model 2 Results:
# Mean Squared Error (MSE): 1978577.5478981638
# Root Mean Squared Error (RMSE): 1406.6191907898042
# R-squared (R2): 0.8517118444220815
# vif value: 6.743626934347744
# Model 3 Results:
# Mean Squared Error (MSE): 2096851.140017635
# Root Mean Squared Error (RMSE): 1448.050807125784
# R-squared (R2): 0.8428476112018054
# vif value: 6.363250394393548

# %%
#5 .Applying Lasso and Ridge methods on the model.

# %%
#ridge regression

from sklearn.linear_model import LinearRegression
LR= LinearRegression()


#====fit the model
LR.fit(X_train,Y_train)

#======predictions
y_pred_train = LR.predict(X_train)
y_pred_test =LR.predict(X_test)

df_coef = pd.concat([pd.DataFrame(list(X_SS)),pd.DataFrame(LR.coef_)], axis=1)
df_coef

# import the model
from sklearn.linear_model import Ridge
RR = Ridge(alpha=300)
RR.fit(X_train,Y_train)
RR.coef_

df_coef["RR_coef"] =RR.coef_
df_coef
# Out:
#            0            0      RR_coef
# 0  Age_08_04 -2257.926049 -1795.525269
# 1         KM  -634.972882  -764.998756
# 2  Fuel_Type   320.204724   103.550467
# 3         HP   309.375607   341.422374
# 4  Automatic    56.238711    45.103400
# 5         cc   -31.188093    24.564482
# 6      Doors   -34.550735    60.438178
# 7     Weight  1237.195566  1007.918515
# 8  Cylinders     0.000000     0.000000
# 9      Gears    99.928890   101.367930

# %%
#lasso regression
from sklearn.linear_model import Lasso
LS = Lasso(alpha=150)
X_train,X_test,Y_train,Y_test  = train_test_split(X_SS,Y,test_size = 0.2,random_state=499)
LS.fit(X_train,Y_train)
LS.coef_

df_coef["LS_coef"] =LS.coef_
df_coef
# Out:
#            0            0      RR_coef      LS_coef
# 0  Age_08_04 -2257.926049 -1795.525269 -2319.434090
# 1         KM  -634.972882  -764.998756  -594.809220
# 2  Fuel_Type   320.204724   103.550467     0.000000
# 3         HP   309.375607   341.422374   392.748102
# 4  Automatic    56.238711    45.103400     0.000000
# 5         cc   -31.188093    24.564482    -0.000000
# 6      Doors   -34.550735    60.438178     0.000000
# 7     Weight  1237.195566  1007.918515   710.662468
# 8  Cylinders     0.000000     0.000000     0.000000
# 9      Gears    99.928890   101.367930     0.000000

# %%
X_new = X_SS.drop(X_SS.columns[[2,4,5,6,8,9]],axis=1)

# %%
X_new
# Out:
#       Age_08_04        KM        HP    Weight
# 0     -1.771966 -0.574695 -0.768042  1.758561
# 1     -1.771966  0.117454 -0.768042  1.758561
# 2     -1.718184 -0.715386 -0.768042  1.758561
# 3     -1.610620 -0.547650 -0.768042  1.758561
# 4     -1.395491 -0.801028 -0.768042  1.853577
# ...         ...       ...       ...       ...
# 1431   0.702015 -1.279939 -1.035138 -0.901883
# 1432   0.863362 -1.321120 -1.035138 -1.091915
# 1433   0.809579 -1.374036 -1.035138 -1.091915
# 1434   0.755797 -1.376703 -1.035138 -1.091915
# 1435   1.078490 -1.827849  0.567440  0.789399
#
# [1436 rows x 4 columns]
